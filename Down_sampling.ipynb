# %%
import SimpleITK as sitk
import os
import matplotlib.pyplot as plt
import nibabel as nb
import numpy as np
from nilearn.image import resample_img

# %%
def listdir_nohidden(path):
    myList = []
    for f in os.listdir(path):
        if not f.startswith('.'):
            myList.append(f)
    return myList

# %%
np.identity
def down_sampling(address, affine):
    orig_nii = nb.load(address)
    downsampled_nii = resample_img(orig_nii, target_affine= affine, interpolation='nearest')

# %%
plt.imshow(orig_nii.dataobj[:,-2,:])
orig_nii.dataobj.shape
# Out:
# (512, 512, 272)

# %%
downsampled_nii = resample_img(orig_nii, target_affine= target_affine, interpolation='nearest', order = "F")

# %%
new_photo = downsampled_nii.dataobj[::,::,::]
plt.imshow(new_photo[:,2,:])

# %%
np.round(orig_nii.affine,2)
# Out:
# array([[-0.36,  0.  ,  0.  , -0.  ],
#        [ 0.  , -0.36,  0.  , -0.  ],
#        [ 0.  ,  0.  ,  0.4 ,  0.  ],
#        [ 0.  ,  0.  ,  0.  ,  1.  ]])

# %%
np.round(downsampled_nii.affine,2)
# Out:
# array([[   1.  ,    0.  ,    0.  , -185.64],
#        [   0.  ,    1.  ,    0.  , -185.64],
#        [   0.  ,    0.  ,    1.  ,    0.  ],
#        [   0.  ,    0.  ,    0.  ,    1.  ]])

# %%
np.diag((1,1,1))
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
target_affine = np.diag((3, 3, 3))
target_affine == 3 * np.eye(3)
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])
